# %% [markdown]
# # **Problem Set 3**

# %% [markdown]
# ## **Tasks**
# - Interpretation of the flowchart
# - Assembling A and S matrices
# - Calculating d, Dpro, Dstr, Dproff, Dprobf, Dprof
# - Answering multiple choice & True/False questions
#
# ## **Passing requirements**
# - **At least 80 points**
# - **Delivering the flowchart on Blackboard in Assignments -> PS3 -> "PS3 - Flowchart"**
#
# **_Please run the cell below before you start the assignment_**

# %%
# Import required Python libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Folder for the files
files_folder = "files_PS3_V1_0/"

# %% [markdown]
# 3.70E+044.00E+058.40E+032.75E+033.50E+60.0054.50E+062.96E+081.55E+051.80E+072.34E+061.15E-061.94E-042.34E-021.41E-035.45E-072.27E-076.73E-061.89E+014.23E+013.40E+022.50E+036.50E-021.60E-018.62E-049.70E-057.90E-054.10E-057.10E-038.75E+028.90E+012.10E+011.43E+01## **Well-To-Wheel (WTW) Problem**
#
# In this problem set, we aim to introduce some structures and ways of modelling different life cycle phases, progressing further ahead with the ICE (internal combustion engine) example. In the previous problem set, we looked at only the construction of the ICE vehicle, or what is typically referred to as a Cradle-to-Gate LCA. In the case of transportation, this is commonly referred to as a Well-to-Tank LCA (WTT). We would now like to incorporate the use phase of the vehicle, as well as the construction and demolition phases of the infrastructure along the ICE’s fuel value chain. In this case this implies modelling the inventory for the infrastructure (refinery and filling station) in the value chain of low-sulphur diesel fuel. An LCA incorporating aspects of the vehicle’s use phase is what is commonly referred to as a Well-to-Wheel LCA (WTW).
#
# **ICE Diesel Value Chain Background Information**
#
# Input and emission data for the construction, operation, and demolition of the vehicle itself, the fuel distribution (FD), and fuel processing/refining (FP) infrastructure is given. The functional unit for the analysis is stated to be 1 km of travel delivered by the same ICE vehicle used in PS2. The vehicle has an expected lifetime of 150 000 km. The background databases, `Abb` and `Sb`, along with the characterization matrix `C`, are assumed the same as that given in PS2.
#
# **_Fuel Production_**
#
# The refinery produces 6000 kton of diesel a year. Lifetime = 30 years. Diesel has a specific energy content of 44 MJ/kg.
#
# _Construction phase_
#
# |Table 1: Requirements for construction of refinery|||
# |-|-|-|
# ||**Unit**|**Quantity**|
# |Concrete|kg|4.50E+06|
# |Electricity|N. Gas kWh|2.96E+08|
# |Plastic|kg|1.55E+05|
# |Steel|kg|1.80E+07|
# |Transport|Truck, tkm|2.34E+06|
#
# No data on stressors in construction phase are available.
#
# _Operation phase_
#
# |Table 2a: Requirements for operation of refinery (pr MJ Diesel)|||
# |-|-|-|
# ||**Unit**|**Quantity**|
# |Electricity|N. Gas kWh|0.005|
#
# |Table 2b: Emissions from operation of refinery (pr MJ Diesel)|||
# |-|-|-|
# ||**Unit**|**Quantity**|
# |CH4|kg|1.15E-06|
# |CO2|kg|1.94E-04|
# |Crude Oil in Res.|kg|2.34E-02|
# |Natural Gas in Res.|m3|1.41E-03|
# |NOX|kg|5.45E-07|
# |PM10|kg|2.27E-07|
# |SO2|kg|6.73E-06|
#
# _Demolition phase_
#
# |Table 3: Requirements for demolition of refinery (pr MJ Diesel)|||
# |-|-|-|
# ||**Unit**|**Quantity**|
# |Transport|Truck, tkm|3.50E+6|
#
# No data on stressors in demolition phase available.
#
# **_Fuel Distribution_**
#
# The throughput of the filling station is 105 TJ (terajoule) of fuel per year. Lifetime = 20 years.
#
# _Construction phase_
#
# |Table 4: Requirements for construction of the filling station|||
# |-|-|-|
# ||**Unit**|**Quantity**|
# |Concrete|kg|3.70E+04|
# |Diesel|MJ|4.00E+05|
# |Steel|kg|8.40E+03|
# |Transport|Truck, tkm|2.75E+03|
#
# No data on stressors in construction phase available.
#
# _Operation phase_
#
# |Table 5: Requirements for operation of the filling station (pr MJ Diesel)|||
# |-|-|-|
# ||**Unit**|**Quantity**|
# |Electricity|N. Gas kWh|8.84E-03|
# |Transport|Truck, tkm|1.14E-03|
#
# Diesel is not as volatile as gasoline so we assume no direct emissions from operation.
#
# _Demolition phase_
#
# |Table 6: Requirements for demolition of the filling station|||
# |-|-|-|
# ||**Unit**|**Quantity**|
# |Transport|Truck, tkm|4.13E+03|
#
# No data on stressors in demolition phase available
#
# **_Car_**
#
# _Construction phase_
#
# |Table 7: Requirements for construction of the car|||
# |-|-|-|
# ||**Unit**|**Quantity**|
# |Aluminium|kg|130.6|
# |Diesel|MJ|3959|
# |Electricity|N. Gas kWh|1000|
# |Glass|kg|42|
# |N. Gas|MJ|14627|
# |Plastic|Mix-kg|89.5|
# |Steel|kg|360|
# |Transport|Truck, tkm|2.22|
#
# |Table 8: Emissions from construction of the car|||
# |-|-|-|
# ||**Unit**|**Quantity**|
# |SO2|kg|1.89E+01|
# |PM10|kg|4.23E+01|
# |NOX|kg|3.40E+02|
# |CO2|kg|2.50E+03|
# |CH4|kg|6.50E-02|
#
# _Operation phase_
#
# Operation of the car requires (per km): Diesel (MJ) 2.18.
#
# |Table 9: Emissions from operation of the car (per km)|||
# |-|-|-|
# ||**Unit**|**Quantity**|
# |CO2|kg|1.60E-01|
# |NOX|kg|8.62E-04|
# |CH4|kg|9.70E-05|
# |PM10|kg|7.90E-05|
# |SO2|kg|4.10E-05|
#
# _Demolition phase_
#
# |Table 10: Requirements for demolition of the car|||
# |-|-|-|
# ||**Unit**|**Quantity**|
# |Diesel|MJ|370|
# |Electricity|N. Gas kWh|96|
# |Transport|Truck, tkm|0.46|
#
# |Table 11: Emissions from demolition of the car (per km)|||
# |-|-|-|
# ||**Unit**|**Quantity**|
# |CH4|kg|7.10E-03|
# |CO2|kg|8.75E+02|
# |NOX|kg|8.90E+01|
# |PM10|kg|2.10E+01|
# |SO2|kg|1.43E+01|

# %% [markdown]
# ## **1. Unidirectional flowchart of the value chain** _(Mandatory for passing the assignment)_

# %% [markdown]
# **Instructions:** Construct a unidirectional flow chart of the value chain that models the different life cycle phases. Label all nodes and flows, with amounts and units. (See figure 4.3 in the reading for Session 6 for how to do it.)
#
# This question does not bring any point per se but is **mandatory** for passing the assignment. You have to deliver the flowchart on Blackboard in the folder (Assignments -> PS3 -> "PS3 - Flowchart"). Even if you get at least 80 points, if you have not delivered the flowchart on Blackboard, your assignment will not get approved.
#
# _The flowchart needs to be readable for us: you can do the flowchart by hand (drawing on paper and taking a picture/scanning) or you can use a software (draw on a tablet, use PowerPoint, Lucidchart, Miro, etc.). Upload the flowchart as pdf/jpeg/png on Blackboard. You can upload a file as many times as you want until the deadline. Therefore, do not hesitate to make sure that the values from your flowchart and A matrix are aligned when you are getting your A matrix checked in the autograded assignment._

# %% [markdown]
# ## **2. A matrix** _(20 points)_

# %% [markdown]
# Your task is to set up the complete `A` matrix. `Abb` is already given. You have to fill in the matrices `Aff`, `Abf`, `Afb`. For that, you have two options:
# - Option 1: filling in the matrices in the csv files located in the **files_PS3_V1_0** folder and save the csv files by using "ctrl+s". **If you are filling in the matrices that way, you should enter the formulas in the table.**
# - Option 2: filling in the matrices in the cells in the sections 2a), 2b), 2c). If you go for that option, we recommend you to make a quick hand sketch of the matrices to visualize how they should look like.
#
# In the matrices:
# - "CICE" means "Construction of the ICE vehicle"
# - "OICE (km)" means "Operation of the ICE vehicle"
# - "DICE" means "Demolition of the ICE vehicle"
# - "CFuel Distribution" means "Construction of the Fuel distribution infrastructure"
# - "OFuel Distribution (MJ Diesel)" means "Operation of the Fuel distribution infrastructure"
# - "DFuel Distribution" means "Demolition of the Fuel distribution infrastructure"
# - "CFuel Processing" means "Construction of the Fuel production infrastructure"
# - "OFuel Processing (MJ Diesel)" means "Operation of the Fuel production infrastructure"
# - "DFuel Processing" means "Demolition of the Fuel production infrastructure"
#
# **Do not hesitate to use the display() function to check you have built the DataFrames as you expect them to be!**

# %% [markdown]
# Run the cell below to import `Aff`, `Abf`, `Afb` and `Abb` as Pandas DataFrames. Do not change the names of the index or columns of the matrices nor their order as the autograding process might return an incorrect answer.

# %%
Aff = pd.read_csv(files_folder + 'Aff.csv', sep = ',', index_col = [0])
Abf = pd.read_csv(files_folder + 'Abf.csv', sep = ',', index_col = [0])
Afb = pd.read_csv(files_folder + 'Afb.csv', sep = ',', index_col = [0])
Abb = pd.read_csv(files_folder + 'Abb.csv', sep = ',', index_col = [0])

### In case formulas are entered in the csv files
for matrix in [Aff, Abf]:
    for row in matrix.index:
        for column in matrix.columns:
            if type(matrix.loc[row, column]) == str:
                if " " in matrix.loc[row, column]:
                    matrix.loc[row, column] = matrix.loc[row, column].lstrip(' ')
                if "=" in matrix.loc[row, column]:
                    matrix.loc[row, column] = matrix.loc[row, column].lstrip('=')
                matrix.loc[row, column] = eval(matrix.loc[row, column])

# %% [markdown]
# #### **2a)** _(5 points)_ Fill in `Aff`

# %%
Aff = Aff.fillna(0)

display(Aff)
# Out:
#                                 CICE  OICE (km)  DICE  CFuel Distribution  \
# CICE                             0.0   0.000007   0.0                 0.0
# OICE (km)                        0.0   0.000000   0.0                 0.0
# DICE                             0.0   0.000007   0.0                 0.0
# CFuel Distribution               0.0   0.000000   0.0                 0.0
# OFuel Distribution (MJ Diesel)   0.0   2.180000   0.0                 0.0
# DFuel Distribution               0.0   0.000000   0.0                 0.0
# CFuel Processing                 0.0   0.000000   0.0                 0.0
# OFuel Processing (MJ Diesel)     0.0   0.000000   0.0                 0.0
# DFuel Processing                 0.0   0.000000   0.0                 0.0
#
#                                 OFuel Distribution (MJ Diesel)  \
# CICE                                              0.000000e+00
# OICE (km)                                         0.000000e+00
# ...

# %% [markdown]
# **_Run the cell under to check the format of your answer(s)_**

# %%
assert Aff.isnull().values.any() == False, 'There are still NaN values in the matrix'
assert (Aff.index == ['CICE', 'OICE (km)', 'DICE', 'CFuel Distribution',
       'OFuel Distribution (MJ Diesel)', 'DFuel Distribution',
       'CFuel Processing', 'OFuel Processing (MJ Diesel)', 'DFuel Processing']).all(), 'The index do not correspond'
assert (Aff.columns == ['CICE', 'OICE (km)', 'DICE', 'CFuel Distribution',
       'OFuel Distribution (MJ Diesel)', 'DFuel Distribution',
       'CFuel Processing', 'OFuel Processing (MJ Diesel)', 'DFuel Processing']).all(), 'The columns do not correspond'

# %% [markdown]
# #### **2b)** _(5 points)_ Fill in `Abf`

# %%
Abf = Abf.fillna(0)

display(Abf)
# Out:
#                               CICE  OICE (km)    DICE  CFuel Distribution  \
# Electricity (N. Gas kWh)   1000.00        0.0   96.00                 0.0
# Steel (kg)                  360.00        0.0    0.00              8400.0
# Aluminium (kg)              130.60        0.0    0.00                 0.0
# Platinum (kg)                 0.00        0.0    0.00                 0.0
# Plastic (kg)                 89.50        0.0    0.00                 0.0
# Diesel (MJ)                3959.00        0.0  370.00            400000.0
# N. Gas (MJ)               14627.00        0.0    0.00                 0.0
# Transport (Truck, tkm)        2.22        0.0    0.46              2750.0
# Concrete (kg)                 0.00        0.0    0.00             37000.0
# Glass (kg)                   42.00        0.0    0.00                 0.0
#
#                           OFuel Distribution (MJ Diesel)  DFuel Distribution  \
# ...

# %% [markdown]
# **_Run the cell under to check the format of your answer(s)_**

# %%
assert Abf.isnull().values.any() == False, 'There are still NaN values in the matrix'
assert (Abf.index == ['Electricity (N. Gas kWh)', 'Steel (kg)', 'Aluminium (kg)',
       'Platinum (kg)', 'Plastic (kg)', 'Diesel (MJ)', 'N. Gas (MJ)',
       'Transport (Truck, tkm)', 'Concrete (kg)', 'Glass (kg)']).all(), 'The index do not correspond'
assert (Abf.columns == ['CICE', 'OICE (km)', 'DICE', 'CFuel Distribution',
       'OFuel Distribution (MJ Diesel)', 'DFuel Distribution',
       'CFuel Processing', 'OFuel Processing (MJ Diesel)', 'DFuel Processing']).all(), 'The columns do not correspond'

# %% [markdown]
# #### **2c)** _(5 points)_ Fill in `Afb`

# %%
Afb = Afb.fillna(0)

display(Afb)
# Out:
#                                 Electricity (N. Gas kWh)  Steel (kg)  \
# CICE                                                 0.0         0.0
# OICE (km)                                            0.0         0.0
# DICE                                                 0.0         0.0
# CFuel Distribution                                   0.0         0.0
# OFuel Distribution (MJ Diesel)                       0.0         0.0
# DFuel Distribution                                   0.0         0.0
# CFuel Processing                                     0.0         0.0
# OFuel Processing (MJ Diesel)                         0.0         0.0
# DFuel Processing                                     0.0         0.0
#
#                                 Aluminium (kg)  Platinum (kg)  Plastic (kg)  \
# CICE                                       0.0            0.0           0.0
# OICE (km)                                  0.0            0.0           0.0
# ...

# %% [markdown]
# **_Run the cell under to check the format of your answer(s)_**

# %%
assert Afb.isnull().values.any() == False, 'There are still NaN values in the matrix'
assert (Afb.index == ['CICE', 'OICE (km)', 'DICE', 'CFuel Distribution',
       'OFuel Distribution (MJ Diesel)', 'DFuel Distribution',
       'CFuel Processing', 'OFuel Processing (MJ Diesel)', 'DFuel Processing']).all(), 'The index do not correspond'
assert (Afb.columns == ['Electricity (N. Gas kWh)', 'Steel (kg)', 'Aluminium (kg)',
       'Platinum (kg)', 'Plastic (kg)', 'Diesel (MJ)', 'N. Gas (MJ)',
       'Transport (Truck, tkm)', 'Concrete (kg)', 'Glass (kg)']).all(), 'The columns do not correspond'

# %% [markdown]
# #### **2d)** _(5 points)_ Assemble `Aff`, `Abf`, `Afb` and `Abb` into `A` matrix

# %%
A1 = pd.concat([Aff, Afb], axis = 1)
A2 = pd.concat([Abf, Abb], axis = 1)
A = pd.concat([A1, A2], axis = 0)
display(A)
# Out:
#                                     CICE  OICE (km)    DICE  \
# CICE                                0.00   0.000007    0.00
# OICE (km)                           0.00   0.000000    0.00
# DICE                                0.00   0.000007    0.00
# CFuel Distribution                  0.00   0.000000    0.00
# OFuel Distribution (MJ Diesel)      0.00   2.180000    0.00
# DFuel Distribution                  0.00   0.000000    0.00
# CFuel Processing                    0.00   0.000000    0.00
# OFuel Processing (MJ Diesel)        0.00   0.000000    0.00
# DFuel Processing                    0.00   0.000000    0.00
# Electricity (N. Gas kWh)         1000.00   0.000000   96.00
# Steel (kg)                        360.00   0.000000    0.00
# Aluminium (kg)                    130.60   0.000000    0.00
# Platinum (kg)                       0.00   0.000000    0.00
# Plastic (kg)                       89.50   0.000000    0.00
# Diesel (MJ)                      3959.00   0.000000  370.00
# ...

# %% [markdown]
# **_Run the cell under to check the format of your answer(s)_**

# %%
assert (A.index == ['CICE', 'OICE (km)', 'DICE', 'CFuel Distribution',
       'OFuel Distribution (MJ Diesel)', 'DFuel Distribution',
       'CFuel Processing', 'OFuel Processing (MJ Diesel)', 'DFuel Processing', 'Electricity (N. Gas kWh)', 'Steel (kg)', 'Aluminium (kg)',
       'Platinum (kg)', 'Plastic (kg)', 'Diesel (MJ)', 'N. Gas (MJ)',
       'Transport (Truck, tkm)', 'Concrete (kg)', 'Glass (kg)']).all(), 'The index do not correspond'
assert (A.columns == ['CICE', 'OICE (km)', 'DICE', 'CFuel Distribution',
       'OFuel Distribution (MJ Diesel)', 'DFuel Distribution',
       'CFuel Processing', 'OFuel Processing (MJ Diesel)', 'DFuel Processing', 'Electricity (N. Gas kWh)', 'Steel (kg)', 'Aluminium (kg)',
       'Platinum (kg)', 'Plastic (kg)', 'Diesel (MJ)', 'N. Gas (MJ)',
       'Transport (Truck, tkm)', 'Concrete (kg)', 'Glass (kg)']).all(), 'The columns do not correspond'

# %% [markdown]
# ## 3. Leontief inverse and output _(10 points)_

# %% [markdown]
# #### **3a)** _(2 points)_ Preliminary steps
#
# To calculate the Leontief inverse, an identity matrix `I` has be defined and the determinant of `(I-A)` has to be checked. Define the identity matrix `I` and calculate the determinant `detIA` of the matrix `(I-A)` in the cell under.

# %%
I = np.identity(19)
detIA = np.linalg.det(I-A)
print(detIA)
# Out:
# 0.9818609900116738

# %% [markdown]
# **_Run the cell under to check the format of your answer(s)_**

# %%
assert type(detIA) == np.float64, 'The answer(s) must be numeric'

# %% [markdown]
# #### **3b)** _(3 points)_ Compute the Leontief matrix `L`

# %%
Larr = np.linalg.inv(I-A)
L = pd.DataFrame(Larr, index = ['CICE', 'OICE (km)', 'DICE', 'CFuel Distribution',
       'OFuel Distribution (MJ Diesel)', 'DFuel Distribution',
       'CFuel Processing', 'OFuel Processing (MJ Diesel)', 'DFuel Processing', 'Electricity (N. Gas kWh)', 'Steel (kg)', 'Aluminium (kg)',
       'Platinum (kg)', 'Plastic (kg)', 'Diesel (MJ)', 'N. Gas (MJ)',
       'Transport (Truck, tkm)', 'Concrete (kg)', 'Glass (kg)'], columns = ['CICE', 'OICE (km)', 'DICE', 'CFuel Distribution',
       'OFuel Distribution (MJ Diesel)', 'DFuel Distribution',
       'CFuel Processing', 'OFuel Processing (MJ Diesel)', 'DFuel Processing', 'Electricity (N. Gas kWh)', 'Steel (kg)', 'Aluminium (kg)',
       'Platinum (kg)', 'Plastic (kg)', 'Diesel (MJ)', 'N. Gas (MJ)',
       'Transport (Truck, tkm)', 'Concrete (kg)', 'Glass (kg)'])
display(L)
# Out:
#                                         CICE     OICE (km)          DICE  \
# CICE                            1.000000e+00  6.666667e-06  2.800416e-17
# OICE (km)                      -0.000000e+00  1.000000e+00 -0.000000e+00
# DICE                           -1.861295e-15  6.666667e-06  1.000000e+00
# CFuel Distribution              4.848086e-18  1.038095e-09 -1.316828e-20
# OFuel Distribution (MJ Diesel) -0.000000e+00  2.180000e+00 -0.000000e+00
# DFuel Distribution              1.399280e-18  1.038095e-09  1.819899e-19
# CFuel Processing                5.876679e-21  2.752525e-13 -2.011390e-22
# OFuel Processing (MJ Diesel)    0.000000e+00  2.180000e+00  0.000000e+00
# DFuel Processing               -7.164408e-21  2.752525e-13 -4.797595e-22
# Electricity (N. Gas kWh)        3.586202e+03  5.584055e-02  1.081166e+02
# Steel (kg)                      3.654278e+02  2.507665e-03  1.531519e-01
# Aluminium (kg)                  1.332185e+02  9.215871e-04  5.835659e-02
# ...

# %% [markdown]
# **_Run the cell under to check the format of your answer(s)_**

# %%
assert (L.index == ['CICE', 'OICE (km)', 'DICE', 'CFuel Distribution',
       'OFuel Distribution (MJ Diesel)', 'DFuel Distribution',
       'CFuel Processing', 'OFuel Processing (MJ Diesel)', 'DFuel Processing', 'Electricity (N. Gas kWh)', 'Steel (kg)', 'Aluminium (kg)',
       'Platinum (kg)', 'Plastic (kg)', 'Diesel (MJ)', 'N. Gas (MJ)',
       'Transport (Truck, tkm)', 'Concrete (kg)', 'Glass (kg)']).all(), 'The index do not correspond'
assert (L.columns == ['CICE', 'OICE (km)', 'DICE', 'CFuel Distribution',
       'OFuel Distribution (MJ Diesel)', 'DFuel Distribution',
       'CFuel Processing', 'OFuel Processing (MJ Diesel)', 'DFuel Processing', 'Electricity (N. Gas kWh)', 'Steel (kg)', 'Aluminium (kg)',
       'Platinum (kg)', 'Plastic (kg)', 'Diesel (MJ)', 'N. Gas (MJ)',
       'Transport (Truck, tkm)', 'Concrete (kg)', 'Glass (kg)']).all(), 'The columns do not correspond'

# %% [markdown]
# #### **3c)** _(2 points)_ Fill in the final demand vector `y`

# %% [markdown]
# Run the cell below to import `y` as Pandas DataFrames. Do not change the names of the index or columns of the matrices nor their order as the autograding process might return an incorrect answer.

# %%
y = pd.read_csv(files_folder + 'y.csv', sep = ',', index_col = [0])

# %% [markdown]
# Write in the cell under to fill in `y`

# %%
y = y.fillna(0)

display(y)
# Out:
#                                 Final demand
# CICE                                     0.0
# OICE (km)                                1.0
# DICE                                     0.0
# CFuel Distribution                       0.0
# OFuel Distribution (MJ Diesel)           0.0
# DFuel Distribution                       0.0
# CFuel Processing                         0.0
# OFuel Processing (MJ Diesel)             0.0
# DFuel Processing                         0.0
# Electricity (N. Gas kWh)                 0.0
# Steel (kg)                               0.0
# Aluminium (kg)                           0.0
# Platinum (kg)                            0.0
# Plastic (kg)                             0.0
# Diesel (MJ)                              0.0
# N. Gas (MJ)                              0.0
# Transport (Truck, tkm)                   0.0
# Concrete (kg)                            0.0
# Glass (kg)                               0.0

# %% [markdown]
# **_Run the cell under to check the format of your answer(s)_**

# %%
assert y.isnull().values.any() == False, 'There are still NaN values in the vector'
assert (y.index == ['CICE', 'OICE (km)', 'DICE', 'CFuel Distribution',
       'OFuel Distribution (MJ Diesel)', 'DFuel Distribution',
       'CFuel Processing', 'OFuel Processing (MJ Diesel)', 'DFuel Processing', 'Electricity (N. Gas kWh)', 'Steel (kg)', 'Aluminium (kg)',
       'Platinum (kg)', 'Plastic (kg)', 'Diesel (MJ)', 'N. Gas (MJ)',
       'Transport (Truck, tkm)', 'Concrete (kg)', 'Glass (kg)']).all(), 'The index do not correspond'
assert (y.columns == ['Final demand']).all(), 'The columns do not correspond'

# %% [markdown]
# #### **3d)** _(3 points)_ Compute the output vector `x` and rename its column into "Output"

# %%
x = L @ y
x = x.rename(columns = {'Final demand' : 'Output'})
display(x)
# Out:
#                                       Output
# CICE                            6.666667e-06
# OICE (km)                       1.000000e+00
# DICE                            6.666667e-06
# CFuel Distribution              1.038095e-09
# OFuel Distribution (MJ Diesel)  2.180000e+00
# DFuel Distribution              1.038095e-09
# CFuel Processing                2.752525e-13
# OFuel Processing (MJ Diesel)    2.180000e+00
# DFuel Processing                2.752525e-13
# Electricity (N. Gas kWh)        5.584055e-02
# Steel (kg)                      2.507665e-03
# Aluminium (kg)                  9.215871e-04
# Platinum (kg)                   5.319701e-14
# Plastic (kg)                    6.089528e-04
# Diesel (MJ)                     4.550400e-02
# N. Gas (MJ)                     7.336536e-01
# Transport (Truck, tkm)          6.575324e-03
# Concrete (kg)                   1.115400e-04
# Glass (kg)                      3.630359e-04

# %% [markdown]
# **_Run the cell under to check the format of your answer(s)_**

# %%
assert (x.columns == ['Output']).all(), 'The column does not correspond'

# %% [markdown]
# ## **4. Contribution analysis** _(30 points)_

# %% [markdown]
# Your task is to set up the complete `S` matrix. `ASb` is already given. You have to fill in the matrices `Sf`. For that, you have two options:
# - Option 1: filling in the matrices in the csv files located in the **files_PS3_V1_0** folder and save the csv files by using "ctrl+s"
# - Option 2: filling in the matrices in the cells in the sections 2a), 2b), 2c). If you go for that option, we recommend you to make a quick hand sketch of the matrices to visualize how they should look like.

# %% [markdown]
# #### **4a)** _(5 points)_ Fill in `Sf`

# %% [markdown]
# Run the cell below to import `Sf` and `Sb` as Pandas DataFrames. Do not change the names of the index or columns of the matrices nor their order as the autograding process might return an incorrect answer.

# %%
Sf = pd.read_csv(files_folder + 'Sf.csv', sep = ',', index_col = [0])
Sb = pd.read_csv(files_folder + 'Sb.csv', sep = ',', index_col = [0])

# %% [markdown]
# Write in the cell under to fill in `Sf`

# %%
Sf = Sf.fillna(0)

display(Sf)
# Out:
#                               CICE  OICE (km)      DICE  CFuel Distribution  \
# Bauxite (kg)                 0.000   0.000000    0.0000                 0.0
# CH4 (kg)                     0.065   0.000097    0.0071                 0.0
# CO2 (kg)                  2500.000   0.160000  875.0000                 0.0
# Crude Oil in Res. (kg)       0.000   0.000000    0.0000                 0.0
# Iron Ore (kg)                0.000   0.000000    0.0000                 0.0
# Natural Gas in Res. (m3)     0.000   0.000000    0.0000                 0.0
# NOx (kg)                   340.000   0.000862   89.0000                 0.0
# Pt (kg)                      0.000   0.000000    0.0000                 0.0
# PM10 (kg)                   42.300   0.000079   21.0000                 0.0
# SO2 (kg)                    18.900   0.000041   14.3000                 0.0
#
#                           OFuel Distribution (MJ Diesel)  DFuel Distribution  \
# ...

# %% [markdown]
# **_Run the cell under to check the format of your answer(s)_**

# %%
assert Sf.isnull().values.any() == False, 'There are still NaN values in the matrix'
assert (Sf.index == ['Bauxite (kg)', 'CH4 (kg)', 'CO2 (kg)', 'Crude Oil in Res. (kg)',
                     'Iron Ore (kg)', 'Natural Gas in Res. (m3)', 'NOx (kg)', 'Pt (kg)',
                     'PM10 (kg)', 'SO2 (kg)']).all(), 'The index do not correspond'
assert (Sf.columns == ['CICE', 'OICE (km)', 'DICE', 'CFuel Distribution',
       'OFuel Distribution (MJ Diesel)', 'DFuel Distribution',
       'CFuel Processing', 'OFuel Processing (MJ Diesel)', 'DFuel Processing']).all(), 'The columns do not correspond'

# %% [markdown]
# #### **4b)** _(4 points)_ Assemble `Sf` and `Sb` into `S` matrix

# %% [markdown]
# Write in the cell under to assemble the `S` matrix

# %%
S = pd.concat([Sf, Sb], axis = 1)
display(S)
# Out:
#                               CICE  OICE (km)      DICE  CFuel Distribution  \
# Bauxite (kg)                 0.000   0.000000    0.0000                 0.0
# CH4 (kg)                     0.065   0.000097    0.0071                 0.0
# CO2 (kg)                  2500.000   0.160000  875.0000                 0.0
# Crude Oil in Res. (kg)       0.000   0.000000    0.0000                 0.0
# Iron Ore (kg)                0.000   0.000000    0.0000                 0.0
# Natural Gas in Res. (m3)     0.000   0.000000    0.0000                 0.0
# NOx (kg)                   340.000   0.000862   89.0000                 0.0
# Pt (kg)                      0.000   0.000000    0.0000                 0.0
# PM10 (kg)                   42.300   0.000079   21.0000                 0.0
# SO2 (kg)                    18.900   0.000041   14.3000                 0.0
#
#                           OFuel Distribution (MJ Diesel)  DFuel Distribution  \
# ...

# %% [markdown]
# **_Run the cell under to check the format of your answer(s)_**

# %%
assert (S.index == ['Bauxite (kg)', 'CH4 (kg)', 'CO2 (kg)', 'Crude Oil in Res. (kg)',
                     'Iron Ore (kg)', 'Natural Gas in Res. (m3)', 'NOx (kg)', 'Pt (kg)',
                     'PM10 (kg)', 'SO2 (kg)']).all(), 'The index do not correspond'
assert (S.columns == ['CICE', 'OICE (km)', 'DICE', 'CFuel Distribution',
       'OFuel Distribution (MJ Diesel)', 'DFuel Distribution',
       'CFuel Processing', 'OFuel Processing (MJ Diesel)', 'DFuel Processing', 'Electricity (N. Gas kWh)', 'Steel (kg)', 'Aluminium (kg)',
       'Platinum (kg)', 'Plastic (kg)', 'Diesel (MJ)', 'N. Gas (MJ)',
       'Transport (Truck, tkm)', 'Concrete (kg)', 'Glass (kg)']).all(), 'The columns do not correspond'

# %% [markdown]
# #### **4c)** _(5 points)_ Compute the vector of impacts `d` and rename its column into "Total impacts"

# %% [markdown]
# Run the cell below to import `C` as Pandas DataFrames.

# %%
C = pd.read_csv(files_folder + 'C.csv', sep = ',', index_col = [0])

# %%
e = S @ x
e = e.rename(columns = {'Output' : 'Stressors'})
display(e)

d = C @ e
d = d.rename(columns = {'Stressors' : 'Total impacts'})
display(d)
# Out:
#                              Stressors
# Bauxite (kg)              1.352216e-03
# CH4 (kg)                  1.047290e-04
# CO2 (kg)                  2.409941e-01
# Crude Oil in Res. (kg)    1.143861e-01
# Iron Ore (kg)             4.614936e-03
# Natural Gas in Res. (m3)  1.979044e-01
# NOx (kg)                  4.058736e-03
# Pt (kg)                   1.104874e-13
# PM10 (kg)                 5.038585e-04
# SO2 (kg)                  2.959343e-04
#      Total impacts
# ADP       0.006000
# GWP       0.243403
# HTP       0.005312
# AP        0.003137

# %% [markdown]
# **_Run the cell under to check the format of your answer(s)_**

# %%
assert (d.columns == ['Total impacts']).all(), 'The column does not correspond'

# %% [markdown]
# #### **4d)** _(8 points)_ Compute the matrix of impacts by processes `Dpro`

# %%
x_i_marr = np.diag(x["Output"])
x_i_m = pd.DataFrame(x_i_marr, index = ['CICE', 'OICE (km)', 'DICE', 'CFuel Distribution',
       'OFuel Distribution (MJ Diesel)', 'DFuel Distribution',
       'CFuel Processing', 'OFuel Processing (MJ Diesel)', 'DFuel Processing', 'Electricity (N. Gas kWh)', 'Steel (kg)', 'Aluminium (kg)',
       'Platinum (kg)', 'Plastic (kg)', 'Diesel (MJ)', 'N. Gas (MJ)',
       'Transport (Truck, tkm)', 'Concrete (kg)', 'Glass (kg)'], columns = ['CICE', 'OICE (km)', 'DICE', 'CFuel Distribution',
       'OFuel Distribution (MJ Diesel)', 'DFuel Distribution',
       'CFuel Processing', 'OFuel Processing (MJ Diesel)', 'DFuel Processing', 'Electricity (N. Gas kWh)', 'Steel (kg)', 'Aluminium (kg)',
       'Platinum (kg)', 'Plastic (kg)', 'Diesel (MJ)', 'N. Gas (MJ)',
       'Transport (Truck, tkm)', 'Concrete (kg)', 'Glass (kg)'])
#display(x_i_m)
#display(S)

E = S @ x_i_m

display(E)

Dpro = C @ E
display(Dpro)
# Out:
#                                   CICE  OICE (km)          DICE  \
# Bauxite (kg)              0.000000e+00   0.000000  0.000000e+00
# CH4 (kg)                  4.333333e-07   0.000097  4.733333e-08
# CO2 (kg)                  1.666667e-02   0.160000  5.833333e-03
# Crude Oil in Res. (kg)    0.000000e+00   0.000000  0.000000e+00
# Iron Ore (kg)             0.000000e+00   0.000000  0.000000e+00
# Natural Gas in Res. (m3)  0.000000e+00   0.000000  0.000000e+00
# NOx (kg)                  2.266667e-03   0.000862  5.933333e-04
# Pt (kg)                   0.000000e+00   0.000000  0.000000e+00
# PM10 (kg)                 2.820000e-04   0.000079  1.400000e-04
# SO2 (kg)                  1.260000e-04   0.000041  9.533333e-05
#
#                           CFuel Distribution  OFuel Distribution (MJ Diesel)  \
# Bauxite (kg)                             0.0                             0.0
# CH4 (kg)                                 0.0                             0.0
# ...

# %% [markdown]
# **_Run the cell under to check the format of your answer(s)_**

# %%
assert (Dpro.index == ['ADP', 'GWP', 'HTP', 'AP']).all(), 'The index do not correspond'
assert (Dpro.columns == ['CICE', 'OICE (km)', 'DICE', 'CFuel Distribution',
       'OFuel Distribution (MJ Diesel)', 'DFuel Distribution',
       'CFuel Processing', 'OFuel Processing (MJ Diesel)', 'DFuel Processing',
       'Electricity (N. Gas kWh)', 'Steel (kg)', 'Aluminium (kg)',
       'Platinum (kg)', 'Plastic (kg)', 'Diesel (MJ)', 'N. Gas (MJ)',
       'Transport (Truck, tkm)', 'Concrete (kg)', 'Glass (kg)']).all(), 'The columns do not correspond'

# %% [markdown]
# #### Which one(s) of these statement(s) is/are correct?
#
# By looking at `Dpro`:
# 1. `Dpro.sum(axis = 1)` gives the d vector (summing each row along the column axis)
# 2. `Dpro.sum(axis = 0)` gives the d vector (summing each column along the index axis)
# 3. The process that gives the most contribution towards ADP is Natural Gas due to extraction, followed by Operation of ICE vehicle (OICE) that gives the same magnitude.
# 4. The process that gives the most contribution towards GWP is Operation of ICE vehicle (OICE) which is natural with a fossil fuel based vehicle.
# 5. The process that gives the most contribution towards HTP is Construction of ICE vehicle (CICE) followed by Operation of ICE vehicle (OICE) and Demolition of ICE vehicle (DICE).
# 6. The process that gives the most contribution towards AP is Construction of Fuel distribution infrastructure.
#
# Define your answer as the variable `answer_4d` (e.g. `answer_4d = {1}` if you think the correct statement is statement {1} and `answer_4d = {1, 2}` if you think the correct statements are statements {1, 2}).

# %%
answer_4d = {1, 4, 5}

# %% [markdown]
# **_Run the cell under to check the format of your answer(s)_**

# %%
assert all (type(i) in [set] for i in [answer_4d]), 'The answer(s) must be a set of values'

# %% [markdown]
# #### **4e)** _(8 points)_ Compute the matrix of impacts by stressors `Dstr`

# %%
e_i_marr = np.diag(e["Stressors"])
e_i_m = pd.DataFrame(e_i_marr, index = ['Bauxite (kg)', 'CH4 (kg)', 'CO2 (kg)', 'Crude Oil in Res. (kg)',
       'Iron Ore (kg)', 'Natural Gas in Res. (m3)', 'NOx (kg)', 'Pt (kg)',
       'PM10 (kg)', 'SO2 (kg)'], columns = ['Bauxite (kg)', 'CH4 (kg)', 'CO2 (kg)', 'Crude Oil in Res. (kg)',
       'Iron Ore (kg)', 'Natural Gas in Res. (m3)', 'NOx (kg)', 'Pt (kg)',
       'PM10 (kg)', 'SO2 (kg)'])
#display(e_i_m)

Dstr = C @ e_i_m
display(Dstr)
# Out:
#      Bauxite (kg)  CH4 (kg)  CO2 (kg)  Crude Oil in Res. (kg)  Iron Ore (kg)  \
# ADP  2.839653e-12  0.000000  0.000000                0.002299   2.215169e-10
# GWP  0.000000e+00  0.002409  0.240994                0.000000   0.000000e+00
# HTP  0.000000e+00  0.000000  0.000000                0.000000   0.000000e+00
# AP   0.000000e+00  0.000000  0.000000                0.000000   0.000000e+00
#
#      Natural Gas in Res. (m3)  NOx (kg)       Pt (kg)  PM10 (kg)  SO2 (kg)
# ADP                  0.003701  0.000000  1.425287e-13   0.000000  0.000000
# GWP                  0.000000  0.000000  0.000000e+00   0.000000  0.000000
# HTP                  0.000000  0.004870  0.000000e+00   0.000413  0.000028
# AP                   0.000000  0.002841  0.000000e+00   0.000000  0.000296

# %% [markdown]
# **_Run the cell under to check the format of your answer(s)_**

# %%
assert (Dstr.index == ['ADP', 'GWP', 'HTP', 'AP']).all(), 'The index do not correspond'
assert (Dstr.columns == ['Bauxite (kg)', 'CH4 (kg)', 'CO2 (kg)', 'Crude Oil in Res. (kg)',
       'Iron Ore (kg)', 'Natural Gas in Res. (m3)', 'NOx (kg)', 'Pt (kg)',
       'PM10 (kg)', 'SO2 (kg)']).all(), 'The columns do not correspond'

# %% [markdown]
# #### Which one(s) of these statement(s) is/are correct?
#
# By looking at `Dstr`:
# 1. `Dstr.sum(axis = 1)` gives the d vector (summing each row along the column axis)
# 2. `Dstr.sum(axis = 0)` gives the d vector (summing each column along the index axis)
# 3. The stressor that give the most contribution towards ADP is Natural Gas extraction.
# 4. The stressor that gives the most contribution towards GWP is CO$_2$.
# 5. The stressor that gives the most contribution towards HTP and AP is NO$_x$.
#
# Define your answer as the variable `answer_4e` (e.g. `answer_4e = {1}` if you think the correct statement is statement {1} and `answer_4e = {1, 2}` if you think the correct statements are statements {1, 2}).

# %%
answer_4e = {1, 3, 4, 5}

# %% [markdown]
# **_Run the cell under to check the format of your answer(s)_**

# %%
assert all (type(i) in [set] for i in [answer_4e]), 'The answer(s) must be a set of values'

# %% [markdown]
# ## **5. Advanced contribution analysis** _(30 points)_

# %% [markdown]
# #### **5a)** _(15 points)_ Preliminary steps

# %% [markdown]
# Define identity matrices of size `Aff` and `Abb`

# %%
I_Aff = np.identity(9)
I_Abb = np.identity(10)

# %% [markdown]
# Get `yf` based on DataFrame `y` (only rows need to be selected as `y` is only one column)

# %%
yf = y.iloc[:9]
display(yf)
# Out:
#                                 Final demand
# CICE                                     0.0
# OICE (km)                                1.0
# DICE                                     0.0
# CFuel Distribution                       0.0
# OFuel Distribution (MJ Diesel)           0.0
# DFuel Distribution                       0.0
# CFuel Processing                         0.0
# OFuel Processing (MJ Diesel)             0.0
# DFuel Processing                         0.0

# %% [markdown]
# Calculate `xf` and rename its column to "Output"

# %%
Larr = np.linalg.inv(I_Aff-Aff)
L_Aff = pd.DataFrame(Larr, index = ['CICE', 'OICE (km)', 'DICE', 'CFuel Distribution',
       'OFuel Distribution (MJ Diesel)', 'DFuel Distribution',
       'CFuel Processing', 'OFuel Processing (MJ Diesel)', 'DFuel Processing'], columns = ['CICE', 'OICE (km)', 'DICE', 'CFuel Distribution',
       'OFuel Distribution (MJ Diesel)', 'DFuel Distribution',
       'CFuel Processing', 'OFuel Processing (MJ Diesel)', 'DFuel Processing'])

xf = L_Aff @ yf
xf = xf.rename(columns = {'Final demand' : 'Output'})
display(xf)
# Out:
#                                       Output
# CICE                            6.666667e-06
# OICE (km)                       1.000000e+00
# DICE                            6.666667e-06
# CFuel Distribution              1.038095e-09
# OFuel Distribution (MJ Diesel)  2.180000e+00
# DFuel Distribution              1.038095e-09
# CFuel Processing                2.752525e-13
# OFuel Processing (MJ Diesel)    2.180000e+00
# DFuel Processing                2.752525e-13

# %% [markdown]
# Calculate `Mbf`

# %%
x_i_marr = np.diag(xf["Output"])
x_i_m = pd.DataFrame(x_i_marr, index = ['CICE', 'OICE (km)', 'DICE', 'CFuel Distribution',
       'OFuel Distribution (MJ Diesel)', 'DFuel Distribution',
       'CFuel Processing', 'OFuel Processing (MJ Diesel)', 'DFuel Processing'], columns = ['CICE', 'OICE (km)', 'DICE', 'CFuel Distribution',
       'OFuel Distribution (MJ Diesel)', 'DFuel Distribution',
       'CFuel Processing', 'OFuel Processing (MJ Diesel)', 'DFuel Processing'])
#display(x_i_m)

Mbf = Abf @ x_i_m
display(Mbf)
# Out:
#                               CICE  OICE (km)      DICE  CFuel Distribution  \
# Electricity (N. Gas kWh)  0.006667        0.0  0.000640            0.000000
# Steel (kg)                0.002400        0.0  0.000000            0.000009
# Aluminium (kg)            0.000871        0.0  0.000000            0.000000
# Platinum (kg)             0.000000        0.0  0.000000            0.000000
# Plastic (kg)              0.000597        0.0  0.000000            0.000000
# Diesel (MJ)               0.026393        0.0  0.002467            0.000415
# N. Gas (MJ)               0.097513        0.0  0.000000            0.000000
# Transport (Truck, tkm)    0.000015        0.0  0.000003            0.000003
# Concrete (kg)             0.000000        0.0  0.000000            0.000038
# Glass (kg)                0.000280        0.0  0.000000            0.000000
#
#                           OFuel Distribution (MJ Diesel)  DFuel Distribution  \
# ...

# %% [markdown]
# Calculate `Xbf`

# %%
Larr = np.linalg.inv(I_Abb-Abb)
L_Abb = pd.DataFrame(Larr, index = ['Electricity (N. Gas kWh)', 'Steel (kg)', 'Aluminium (kg)',
       'Platinum (kg)', 'Plastic (kg)', 'Diesel (MJ)', 'N. Gas (MJ)',
       'Transport (Truck, tkm)', 'Concrete (kg)', 'Glass (kg)'], columns = ['Electricity (N. Gas kWh)', 'Steel (kg)', 'Aluminium (kg)',
       'Platinum (kg)', 'Plastic (kg)', 'Diesel (MJ)', 'N. Gas (MJ)',
       'Transport (Truck, tkm)', 'Concrete (kg)', 'Glass (kg)'])

Xbf = L_Abb @ Mbf
display(Xbf)
# Out:
#                                   CICE  OICE (km)          DICE  \
# Electricity (N. Gas kWh)  2.390801e-02        0.0  7.207776e-04
# Steel (kg)                2.436185e-03        0.0  1.021013e-06
# Aluminium (kg)            8.881236e-04        0.0  3.890439e-07
# Platinum (kg)             1.841211e-14        0.0  3.884877e-16
# Plastic (kg)              6.013145e-04        0.0  1.035150e-07
# Diesel (MJ)               3.186769e-02        0.0  2.582295e-03
# N. Gas (MJ)               3.723654e-01        0.0  8.149742e-03
# Transport (Truck, tkm)    2.215926e-03        0.0  4.673704e-05
# Concrete (kg)             3.752583e-05        0.0  4.736841e-07
# Glass (kg)                3.080678e-04        0.0  5.914232e-07
#
#                           CFuel Distribution  OFuel Distribution (MJ Diesel)  \
# Electricity (N. Gas kWh)        1.306698e-05                    2.006699e-02
# Steel (kg)                      8.828353e-06                    4.676887e-05
# ...

# %% [markdown]
# **_Run the cell under to check the format of your answer(s)_**

# %%
assert (Xbf.index == ['Electricity (N. Gas kWh)', 'Steel (kg)', 'Aluminium (kg)',
       'Platinum (kg)', 'Plastic (kg)', 'Diesel (MJ)', 'N. Gas (MJ)',
       'Transport (Truck, tkm)', 'Concrete (kg)', 'Glass (kg)']).all(), 'The index do not correspond'
assert (Xbf.columns == ['CICE', 'OICE (km)', 'DICE', 'CFuel Distribution',
       'OFuel Distribution (MJ Diesel)', 'DFuel Distribution',
       'CFuel Processing', 'OFuel Processing (MJ Diesel)', 'DFuel Processing']).all(), 'The columns do not correspond'

# %% [markdown]
# **True or False?**
#
# `Xbf` gives us the total output from the different background processes due to the demand of each foreground process. This helps us to see which of the foreground processes demands the most output of the different processes in the background matrix, which can help us understand which foreground processes contribute mostly to the impacts associated with the background processes.
#
# Define your answer as the variable `answer_5a` (e.g. `answer_5a = True` if you think the statement is True and `answer_5a = False` if you think the statement is False).

# %%
answer_5a = True

# %% [markdown]
# **_Run the cell under to check the format of your answer(s)_**

# %%
assert all (type(i) in [bool] for i in [answer_5a]), 'The answer(s) must be a set of values'

# %% [markdown]
# #### **5b)** _(10 points)_ Dproff, Dprobf, and Dprof to assess the environmental impacts associated with all phases and steps in the value chain

# %% [markdown]
# Calculate `Dproff`

# %%
Dproff = C @ Sf @ x_i_m
display(Dproff)
# Out:
#          CICE  OICE (km)      DICE  CFuel Distribution  \
# ADP  0.000000   0.000000  0.000000                 0.0
# GWP  0.016677   0.162231  0.005834                 0.0
# HTP  0.002963   0.001103  0.000836                 0.0
# AP   0.001713   0.000644  0.000511                 0.0
#
#      OFuel Distribution (MJ Diesel)  DFuel Distribution  CFuel Processing  \
# ADP                             0.0                 0.0               0.0
# GWP                             0.0                 0.0               0.0
# HTP                             0.0                 0.0               0.0
# AP                              0.0                 0.0               0.0
#
#      OFuel Processing (MJ Diesel)  DFuel Processing
# ADP                      0.001083               0.0
# GWP                      0.000481               0.0
# HTP                      0.000003               0.0
# AP                       0.000016               0.0

# %% [markdown]
# Calculate `Dprobf`

# %%
Dprobf = C @ Sb @ Xbf
display(Dprobf)
# Out:
#          CICE  OICE (km)      DICE  CFuel Distribution  \
# ADP  0.002629        0.0  0.000098        1.010915e-05
# GWP  0.028494        0.0  0.000917        6.829382e-05
# HTP  0.000198        0.0  0.000006        3.458662e-07
# AP   0.000130        0.0  0.000004        2.673082e-07
#
#      OFuel Distribution (MJ Diesel)  DFuel Distribution  CFuel Processing  \
# ADP                        0.001485        4.602731e-07      5.253261e-06
# GWP                        0.018873        2.830515e-06      7.810790e-05
# HTP                        0.000133        2.141834e-08      5.224955e-07
# AP                         0.000079        1.457901e-08      3.080685e-07
#
#      OFuel Processing (MJ Diesel)  DFuel Processing
# ADP                      0.000689      1.034255e-07
# GWP                      0.009747      6.360300e-07
# HTP                      0.000068      4.812801e-09
# AP                       0.000040      3.275973e-09

# %% [markdown]
# Calculate `Dprof`

# %%
Dprof = Dproff + Dprobf
display(Dprof)
# Out:
#          CICE  OICE (km)      DICE  CFuel Distribution  \
# ADP  0.002629   0.000000  0.000098        1.010915e-05
# GWP  0.045171   0.162231  0.006751        6.829382e-05
# HTP  0.003162   0.001103  0.000842        3.458662e-07
# AP   0.001843   0.000644  0.000514        2.673082e-07
#
#      OFuel Distribution (MJ Diesel)  DFuel Distribution  CFuel Processing  \
# ADP                        0.001485        4.602731e-07      5.253261e-06
# GWP                        0.018873        2.830515e-06      7.810790e-05
# HTP                        0.000133        2.141834e-08      5.224955e-07
# AP                         0.000079        1.457901e-08      3.080685e-07
#
#      OFuel Processing (MJ Diesel)  DFuel Processing
# ADP                      0.001772      1.034255e-07
# GWP                      0.010227      6.360300e-07
# HTP                      0.000071      4.812801e-09
# AP                       0.000056      3.275973e-09

# %% [markdown]
# **_Run the cell under to check the format of your answer(s)_**

# %%
assert (Dprof.index == ['ADP', 'GWP', 'HTP', 'AP']).all(), 'The index do not correspond'
assert (Dprof.columns == ['CICE', 'OICE (km)', 'DICE', 'CFuel Distribution',
       'OFuel Distribution (MJ Diesel)', 'DFuel Distribution',
       'CFuel Processing', 'OFuel Processing (MJ Diesel)', 'DFuel Processing']).all(), 'The columns do not correspond'

# %% [markdown]
# #### Which one(s) of these statement(s) is/are correct?
#
# By looking at `Dproff`, `Dprobf`, and `Dprof`:
# 1. The `Dproff` matrix shows the environmental impacts for the four impact categories considered due to the direct stressor emissions/extractions at the given foreground processes.
# 2. The `Dprobf` matrix shows the environmental impacts for the four impact categories considered due to the indirect demand of each foreground process on the background subset of processes.
# 3. The `Dprof` matrix gives us the total impacts per foreground process. This means the direct impacts from the foreground processes, as well as the impacts from the background processes due to the demand that each foreground process places on the background processes. In other words we can gain insight into which foreground processes are responsible for the environmental impacts in both the foreground and the background.
#
# Define your answer as the variable `answer_5b` (e.g. `answer_5b = {1}` if you think the correct statement is statement {1} and `answer_5b = {1, 2}` if you think the correct statements are statements {1, 2}).

# %%
answer_5b = {1, 2, 3}

# %% [markdown]
# **_Run the cell under to check the format of your answer(s)_**

# %%
assert all (type(i) in [set] for i in [answer_5b]), 'The answer(s) must be a set of values'

# %% [markdown]
# #### **5c)** _(5 points)_ Illustrate `Dprof` in a ‘100% horizontal stacked bar’ chart with labels

# %% [markdown]
# You should first prepare `Dprof` which will be plotted, name the DataFrame `Dprof_plot`

# %%
Dprof_plot = Dprof.copy()
Dprof_plot.loc['ADP'] = Dprof_plot.loc['ADP']/Dprof_plot.loc['ADP'].sum(axis = 0)*100
Dprof_plot.loc['GWP'] = Dprof_plot.loc['GWP']/Dprof_plot.loc['GWP'].sum(axis = 0)*100
Dprof_plot.loc['HTP'] = Dprof_plot.loc['HTP']/Dprof_plot.loc['HTP'].sum(axis = 0)*100
Dprof_plot.loc['AP'] = Dprof_plot.loc['AP']/Dprof_plot.loc['AP'].sum(axis = 0)*100

# %% [markdown]
# **_Run the cell under to check the format of your answer(s)_**

# %%
assert np.isclose(Dprof_plot.sum(axis = 1).values, np.array([100, 100, 100, 100]), atol=1e-20).all(), 'Dprof_plot should be calculated to make a 100% horizontal stacked bar'

# %% [markdown]
# **_Run the cell under to create the ‘100% horizontal stacked bar’ chart with labels - You do not need to change anything!_**

# %%
# Create stacked bar chart
Dprof_plot.plot(kind='barh', stacked=True)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %% [markdown]
# ## **6. Some interpretation questions** _(10 points)_

# %% [markdown]
# #### **6a)** _(5 points)_ Which one(s) of these statement(s) is/are correct?
#
# By looking at `Dprof` and the ‘100% horizontal stacked bar’ illustrating it:
# 1. The operation of the car dominates the GWP impact category.
# 2. The construction of the fuel refinery does not contribute to any impact category.
# 3. The construction of the car dominates the AP impact category.
#
# Define your answer as the variable `answer_6a` (e.g. `answer_6a = {1}` if you think the correct statement is statement {1} and `answer_6a = {1, 2}` if you think the correct statements are statements {1, 2}).

# %%
answer_6a = {1, 3}

# %% [markdown]
# **_Run the cell under to check the format of your answer(s)_**

# %%
assert all (type(i) in [set] for i in [answer_6a]), 'The answer(s) must be a set of values'

# %% [markdown]
# #### **6b)** _(5 points)_ Which one(s) of these statement(s) is/are correct?
#
# By applying the same transformation done for `Dprof` to another of the matrices you have calculed:
# 1. CO$_2$ contributes to around 87% of the GWP impact category.
# 2. Crude oil contributes to around 38% of the ADP impact category.
# 3. PM$_{10}$ is the main contributor to HTP impact categry.
# 4. SO$_2$ contributes to around 9% of the AP impact category.
#
# Define your answer as the variable `answer_6b` (e.g. `answer_6b = {1}` if you think the correct statement is statement {1} and `answer_6b = {1, 2}` if you think the correct statements are statements {1, 2}).

# %%
answer_6b = {2, 4}

# %% [markdown]
# **_Run the cell under to check the format of your answer(s)_**

# %%
assert all (type(i) in [set] for i in [answer_6b]), 'The answer(s) must be a set of values'
